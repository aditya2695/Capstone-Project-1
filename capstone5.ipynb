# %% [markdown]
# # A program For Photographers Event

# %% [markdown]
# ## Introduction

# %% [markdown]
# ABC Events is a company based in Mumbai for organizing events, It plans to conduct a photography workshop for 5 days for a group of interested applicants from India.The company has to put a good program, including a hotel of residence, places of landscape to visit and click photos and restaurants. So the company’s purpose is to make a list of hotels,including the nearest restaurants, parks for each place.

# %% [markdown]
# ## Data Description

# %% [markdown]
# The data used in this project is provided by Foursquare location data. The data are grouped by landscape area, and each area included the information about this area and all information about restaurants, hotels, and parks which in this area.

# %% [markdown]
# # Table of contents

# %% [markdown]
# # Import Libraries

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
print('libraries imported')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2019.9.11-py36_0              --> 2019.9.11-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2019.10.16-0                  --> 2019.9.11-hecc5488_0 conda-forge
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2019 | 144 KB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         868 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.2.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# libraries imported

# %% [markdown]
# # Define Foursquare Credentials

# %%
ClIENT_ID = 'A3CTF34TTNS3DT2QNQO2ED1FJPDBRIGV4CMJNPYBLOFMSHSS' # your Foursquare ID
ClIENT_SECRET = 'C02Q4L0GFUDV0YETTRQ11Z0OY1H4QVSZUZ5PUYCJ2SJKVFE1' # your Foursquare Secret
VERSION = '20191108'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: A3CTF34TTNS3DT2QNQO2ED1FJPDBRIGV4CMJNPYBLOFMSHSS
# Foursquare_Secret:C02Q4L0GFUDV0YETTRQ11Z0OY1H4QVSZUZ5PUYCJ2SJKVFE1

# %% [markdown]
# # Define the city and get its latitude & longitude

# %%
# define the city and get its latitude & longitude 
city = 'Mumbai'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 18.9387711 72.8353355

# %% [markdown]
# # Obtain Event location

# %%
# define the address of event location and get its latitude & longitude 
address = '16 Gunbow Street,Mumbai'
geolocator = Nominatim(user_agent="foursquare_agent")
event_location = geolocator.geocode(address)
event_latitude = event_location.latitude
event_longitude = event_location.longitude
print(event_latitude, event_longitude)
# Out:
# 18.9347749 72.8344431

# %% [markdown]
# # Search for hotels

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=A3CTF34TTNS3DT2QNQO2ED1FJPDBRIGV4CMJNPYBLOFMSHSS&client_secret=C02Q4L0GFUDV0YETTRQ11Z0OY1H4QVSZUZ5PUYCJ2SJKVFE1&ll=18.9387711,72.8353355&v=20191108&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dc7c0b9a6ec98002c69fc97'},
#  'response': {'venues': [{'id': '4bcf4de40ffdce72215fb2c0',
#     'name': 'Residency Hotel',
#     'location': {'address': '26, Corner of D.N. Road and Rustom Sidhwa Marg, Fort',
#      'lat': 18.934977866806896,
#      'lng': 72.83348094090624,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.934977866806896,
#        'lng': 72.83348094090624}],
#      'distance': 465,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['26, Corner of D.N. Road and Rustom Sidhwa Marg, Fort',
#       'Mumbai 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4e135a03a809291902c7d32f',
#     'name': 'Hotel Traveller’s Inn',
#     'location': {'address': '26, ADI Marzban Path',
#      'crossStreet': 'Behind Cafe Universal, Ballard Estate, Fort',
#      'lat': 18.936039028552536,
#      'lng': 72.83799995101162,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.936039028552536,
#        'lng': 72.83799995101162}],
#      'distance': 413,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['26, ADI Marzban Path (Behind Cafe Universal, Ballard Estate, Fort)',
#       'Mumbai 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1f8931735',
#       'name': 'Bed & Breakfast',
#       'pluralName': 'Bed & Breakfasts',
#       'shortName': 'B & B',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/bedandbreakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4cbc460f9552b60c8d81e48b',
#     'name': 'City Palace Hotel',
#     'location': {'lat': 18.93897,
#      'lng': 72.83561,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93897,
#        'lng': 72.83561}],
#      'distance': 36,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4ffaf206e4b0a0306dd1271d',
#     'name': 'Hotel City Palace',
#     'location': {'address': 'Near CST',
#      'lat': 18.93847362379592,
#      'lng': 72.83459946384183,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93847362379592,
#        'lng': 72.83459946384183}],
#      'distance': 84,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Near CST', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '511cfaa2e4b0d31a018b152b',
#     'name': 'Hotel Windsor',
#     'location': {'address': 'Kumptha 10',
#      'lat': 18.936808168778548,
#      'lng': 72.83832678180758,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.936808168778548,
#        'lng': 72.83832678180758}],
#      'distance': 383,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Kumptha 10', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1ee931735',
#       'name': 'Hostel',
#       'pluralName': 'Hostels',
#       'shortName': 'Hostel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '5321eed6498e273e35971c04',
#     'name': 'sheel hotel',
#     'location': {'lat': 18.93821144054106,
#      'lng': 72.8357245890497,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93821144054106,
#        'lng': 72.8357245890497}],
#      'distance': 74,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4d31c9a072a8b1f7878797d0',
#     'name': 'Hotel Fountain Plaza',
#     'location': {'address': 'panthaky house, Raghunath dadaji street',
#      'crossStreet': 'Kalaghoda, Fort',
#      'lat': 18.93567108713781,
#      'lng': 72.83402982832185,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93567108713781,
#        'lng': 72.83402982832185}],
#      'distance': 371,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['panthaky house, Raghunath dadaji street (Kalaghoda, Fort)',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4f3e6f67e4b090fd1717b9ea',
#     'name': 'hotel kalapi',
#     'location': {'lat': 18.938183969494947,
#      'lng': 72.83780172963147,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.938183969494947,
#        'lng': 72.83780172963147}],
#      'distance': 267,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1fb931735',
#       'name': 'Motel',
#       'pluralName': 'Motels',
#       'shortName': 'Motel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '5121e326e4b0293c8253ab3b',
#     'name': 'Hotel Landmark Fort',
#     'location': {'address': '249 P D Mello Road',
#      'crossStreet': 'Near GPO, Fort',
#      'lat': 18.93852795728219,
#      'lng': 72.83799790310442,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93852795728219,
#        'lng': 72.83799790310442}],
#      'distance': 281,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['249 P D Mello Road (Near GPO, Fort)',
#       'Mumbai 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1f8931735',
#       'name': 'Bed & Breakfast',
#       'pluralName': 'Bed & Breakfasts',
#       'shortName': 'B & B',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/bedandbreakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4ecc40cb9adf1839a0f164d1',
#     'name': 'Colaba Grand Hotel',
#     'location': {'address': 'Colaba',
#      'lat': 18.939656420047406,
#      'lng': 72.83645736010988,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.939656420047406,
#        'lng': 72.83645736010988}],
#      'distance': 153,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Colaba', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '5a84a6e3d1a40227bf2ea3c5',
#     'name': 'Hotel Landmark Annexe',
#     'location': {'lat': 18.93803,
#      'lng': 72.838844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93803,
#        'lng': 72.838844}],
#      'distance': 378,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mumbai 400001', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '5ac2ef59bed4830d66788006',
#     'name': 'Hotel Ankitakshita',
#     'location': {'lat': 18.935698,
#      'lng': 72.837123,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.935698,
#        'lng': 72.837123}],
#      'distance': 390,
#      'postalCode': '400023',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mumbai 400023', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4ec8942849010f98cde5bc97',
#     'name': 'Hotel Arkshita',
#     'location': {'lat': 18.935646575419383,
#      'lng': 72.83731129525782,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.935646575419383,
#        'lng': 72.83731129525782}],
#      'distance': 405,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '54932af2498e3b3acb749ec6',
#     'name': 'Hotel Ashoka',
#     'location': {'lat': 18.942740637228336,
#      'lng': 72.83450137575706,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.942740637228336,
#        'lng': 72.83450137575706}],
#      'distance': 450,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '5010ebebe4b06bc0bc4bb05e',
#     'name': 'Hotel Anand Bhuvan',
#     'location': {'address': 'Opposite Shahid bhagat Singh Road',
#      'crossStreet': 'Fort',
#      'lat': 18.935345300594207,
#      'lng': 72.83688432805798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.935345300594207,
#        'lng': 72.83688432805798}],
#      'distance': 414,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Opposite Shahid bhagat Singh Road (Fort)',
#       'Mumbai 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4d0c40f2e0b98cfa3a28d493',
#     'name': 'Hotel Outram',
#     'location': {'lat': 18.936418,
#      'lng': 72.831732,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.936418,
#        'lng': 72.831732}],
#      'distance': 461,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4e93f5fc49015a5ff4680d44',
#     'name': 'Hotel Dolphin',
#     'location': {'address': '327,SBS Road',
#      'crossStreet': 'Fort',
#      'lat': 18.9345666,
#      'lng': 72.8369424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.9345666,
#        'lng': 72.8369424}],
#      'distance': 497,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['327,SBS Road (Fort)',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4d08e39984ec224b880e2c62',
#     'name': 'Welcome Hotel',
#     'location': {'address': '257 Shahid Bhagat Singh Rd.',
#      'crossStreet': 'Near GPO',
#      'lat': 18.937703430978708,
#      'lng': 72.83746708040115,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.937703430978708,
#        'lng': 72.83746708040115}],
#      'distance': 253,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['257 Shahid Bhagat Singh Rd. (Near GPO)',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fb931735',
#       'name': 'Motel',
#       'pluralName': 'Motels',
#       'shortName': 'Motel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '5306c6e9498e2adaad0066a8',
#     'name': 'landmark hotel mumbai',
#     'location': {'lat': 18.938465389795756,
#      'lng': 72.83821715562256,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.938465389795756,
#        'lng': 72.83821715562256}],
#      'distance': 305,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '52f865d3498e92ebee122292',
#     'name': 'hotel golden palm fort',
#     'location': {'address': 'Fort',
#      'lat': 18.933103326760417,
#      'lng': 72.834628313271,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.933103326760417,
#        'lng': 72.834628313271}],
#      'distance': 635,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Fort', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '5ae8a6b03ba767002cd296da',
#     'name': 'A.k. International Hotel',
#     'location': {'lat': 18.935867,
#      'lng': 72.837875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.935867,
#        'lng': 72.837875}],
#      'distance': 419,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '518534eb498edeec015edb68',
#     'name': 'Deluxe Hotel',
#     'location': {'address': '287 Shahid Bhagat Singh Road',
#      'lat': 18.935690081316263,
#      'lng': 72.83739784257197,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.935690081316263,
#        'lng': 72.83739784257197}],
#      'distance': 405,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Fort',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['287 Shahid Bhagat Singh Road',
#       'Fort 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'shortName': 'Housing Development',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4ec38dd8e5fa690c1ec4f368',
#     'name': 'Benazeer Hotel',
#     'location': {'address': '16 Gunbow Street',
#      'crossStreet': 'Fort',
#      'lat': 18.93514,
#      'lng': 72.833948,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93514,
#        'lng': 72.833948}],
#      'distance': 429,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['16 Gunbow Street (Fort)',
#       'Mumbai 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '53bba963498e32469ef17ce7',
#     'name': 'Cenora Hotel',
#     'location': {'lat': 18.934916,
#      'lng': 72.836969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.934916,
#        'lng': 72.836969}],
#      'distance': 462,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '52076bba11d28f6b8db818e5',
#     'name': "Whatson's Hotel",
#     'location': {'address': 'Fort',
#      'lat': 18.9346619,
#      'lng': 72.83677759999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.9346619,
#        'lng': 72.83677759999999}],
#      'distance': 481,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Fort', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '51923bdb454a8a1ab5dfca73',
#     'name': 'Mumbai Hotels, India',
#     'location': {'address': 'Mumbai',
#      'lat': 18.939615817254744,
#      'lng': 72.83566474914551,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.939615817254744,
#        'lng': 72.83566474914551}],
#      'distance': 100,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mumbai', 'Mumbai', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False},
#    {'id': '4c72283a13228cfaa7692a65',
#     'name': 'New Anand Bhavan',
#     'location': {'address': 'Sheri House',
#      'crossStreet': 'Cawasji Patel Street, near gunbow street',
#      'lat': 18.93465565029344,
#      'lng': 72.83484756882122,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.93465565029344,
#        'lng': 72.83484756882122}],
#      'distance': 460,
#      'postalCode': '400023',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Sheri House (Cawasji Patel Street, near gunbow street)',
#       'Mumbai 400023',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372089',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1f8931735', 'name': 'B...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3                                                 []    False
# 4  [{'id': '4bf58dd8d48988d1ee931735', 'name': 'H...    False
#
#                          id  \
# 0  4bcf4de40ffdce72215fb2c0
# 1  4e135a03a809291902c7d32f
# 2  4cbc460f9552b60c8d81e48b
# 3  4ffaf206e4b0a0306dd1271d
# 4  511cfaa2e4b0d31a018b152b
#
#                                     location.address location.cc  \
# 0  26, Corner of D.N. Road and Rustom Sidhwa Marg...          IN
# 1                               26, ADI Marzban Path          IN
# 2                                                NaN          IN
# 3                                           Near CST          IN
# 4                                         Kumptha 10          IN
#
#   location.city location.country                         location.crossStreet  \
# 0        Mumbai            India                                          NaN
# 1        Mumbai            India  Behind Cafe Universal, Ballard Estate, Fort
# 2           NaN            India                                          NaN
# 3        Mumbai            India                                          NaN
# 4        Mumbai            India                                          NaN
#
#    location.distance                          location.formattedAddress  \
# 0                465  [26, Corner of D.N. Road and Rustom Sidhwa Mar...
# 1                413  [26, ADI Marzban Path (Behind Cafe Universal, ...
# 2                 36                                            [India]
# 3                 84             [Near CST, Mumbai, Mahārāshtra, India]
# 4                383           [Kumptha 10, Mumbai, Mahārāshtra, India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 18.93497786680689...     18.934978
# 1  [{'label': 'display', 'lat': 18.93603902855253...     18.936039
# 2  [{'label': 'display', 'lat': 18.93897, 'lng': ...     18.938970
# 3  [{'label': 'display', 'lat': 18.93847362379592...     18.938474
# 4  [{'label': 'display', 'lat': 18.93680816877854...     18.936808
#
#    location.lng location.postalCode location.state                   name  \
# 0     72.833481              400001    Mahārāshtra        Residency Hotel
# 1     72.838000              400001    Mahārāshtra  Hotel Traveller’s Inn
# 2     72.835610                 NaN            NaN      City Palace Hotel
# 3     72.834599                 NaN    Mahārāshtra      Hotel City Palace
# 4     72.838327                 NaN    Mahārāshtra          Hotel Windsor
#
#      referralId
# 0  v-1573372089
# 1  v-1573372089
# 2  v-1573372089
# 3  v-1573372089
# 4  v-1573372089

# %% [markdown]
# # Clean Hotel Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                     name       categories  \
# 0        Residency Hotel            Hotel
# 1  Hotel Traveller’s Inn  Bed & Breakfast
# 2      City Palace Hotel            Hotel
# 3      Hotel City Palace             None
# 4          Hotel Windsor           Hostel
#
#                                              address  cc    city country  \
# 0  26, Corner of D.N. Road and Rustom Sidhwa Marg...  IN  Mumbai   India
# 1                               26, ADI Marzban Path  IN  Mumbai   India
# 2                                                NaN  IN     NaN   India
# 3                                           Near CST  IN  Mumbai   India
# 4                                         Kumptha 10  IN  Mumbai   India
#
#                                    crossStreet  distance  \
# 0                                          NaN       465
# 1  Behind Cafe Universal, Ballard Estate, Fort       413
# 2                                          NaN        36
# 3                                          NaN        84
# 4                                          NaN       383
#
#                                     formattedAddress  \
# 0  [26, Corner of D.N. Road and Rustom Sidhwa Mar...
# 1  [26, ADI Marzban Path (Behind Cafe Universal, ...
# 2                                            [India]
# 3             [Near CST, Mumbai, Mahārāshtra, India]
# 4           [Kumptha 10, Mumbai, Mahārāshtra, India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 18.93497786680689...  18.934978  72.833481
# 1  [{'label': 'display', 'lat': 18.93603902855253...  18.936039  72.838000
# 2  [{'label': 'display', 'lat': 18.93897, 'lng': ...  18.938970  72.835610
# 3  [{'label': 'display', 'lat': 18.93847362379592...  18.938474  72.834599
# 4  [{'label': 'display', 'lat': 18.93680816877854...  18.936808  72.838327
#
#   postalCode        state                        id
# 0     400001  Mahārāshtra  4bcf4de40ffdce72215fb2c0
# 1     400001  Mahārāshtra  4e135a03a809291902c7d32f
# 2        NaN          NaN  4cbc460f9552b60c8d81e48b
# 3        NaN  Mahārāshtra  4ffaf206e4b0a0306dd1271d
# 4        NaN  Mahārāshtra  511cfaa2e4b0d31a018b152b

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_dataframe2
# Out:
#                         name                                categories  \
# 0            Residency Hotel                                     Hotel
# 1      Hotel Traveller’s Inn                           Bed & Breakfast
# 2          City Palace Hotel                                     Hotel
# 3          Hotel City Palace                                      None
# 4              Hotel Windsor                                    Hostel
# 5                sheel hotel                                     Hotel
# 6       Hotel Fountain Plaza                         Indian Restaurant
# 7               hotel kalapi                                     Motel
# 8        Hotel Landmark Fort                           Bed & Breakfast
# 9         Colaba Grand Hotel                                 Hotel Bar
# 10     Hotel Landmark Annexe                                     Hotel
# 11        Hotel Ankitakshita                                     Hotel
# 12            Hotel Arkshita                               Snack Place
# 13              Hotel Ashoka                         Indian Restaurant
# 14        Hotel Anand Bhuvan                      Fast Food Restaurant
# 15              Hotel Outram                                     Hotel
# 16             Hotel Dolphin                                     Hotel
# 17             Welcome Hotel                                     Motel
# 18     landmark hotel mumbai  Residential Building (Apartment / Condo)
# 19    hotel golden palm fort                                Hotel Pool
# 20  A.k. International Hotel                                     Hotel
# 21              Deluxe Hotel                       Housing Development
# 22            Benazeer Hotel                                     Hotel
# 23              Cenora Hotel                          Asian Restaurant
# 24           Whatson's Hotel                                     Hotel
# 25      Mumbai Hotels, India                                     Hotel
# 26          New Anand Bhavan                      Fast Food Restaurant
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 1                                26, ADI Marzban Path  18.936039  72.838000
# 2                                                 NaN  18.938970  72.835610
# 3                                            Near CST  18.938474  72.834599
# 4                                          Kumptha 10  18.936808  72.838327
# 5                                                 NaN  18.938211  72.835725
# 6             panthaky house, Raghunath dadaji street  18.935671  72.834030
# 7                                                 NaN  18.938184  72.837802
# 8                                  249 P D Mello Road  18.938528  72.837998
# 9                                              Colaba  18.939656  72.836457
# 10                                                NaN  18.938030  72.838844
# 11                                                NaN  18.935698  72.837123
# 12                                                NaN  18.935647  72.837311
# 13                                                NaN  18.942741  72.834501
# 14                  Opposite Shahid bhagat Singh Road  18.935345  72.836884
# 15                                                NaN  18.936418  72.831732
# 16                                       327,SBS Road  18.934567  72.836942
# 17                        257 Shahid Bhagat Singh Rd.  18.937703  72.837467
# 18                                                NaN  18.938465  72.838217
# 19                                               Fort  18.933103  72.834628
# 20                                                NaN  18.935867  72.837875
# 21                       287 Shahid Bhagat Singh Road  18.935690  72.837398
# 22                                   16 Gunbow Street  18.935140  72.833948
# 23                                                NaN  18.934916  72.836969
# 24                                               Fort  18.934662  72.836778
# 25                                             Mumbai  18.939616  72.835665
# 26                                        Sheri House  18.934656  72.834848
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 1      400001  Mahārāshtra
# 2         NaN          NaN
# 3         NaN  Mahārāshtra
# 4         NaN  Mahārāshtra
# 5         NaN          NaN
# 6         NaN  Mahārāshtra
# 7         NaN          NaN
# 8      400001  Mahārāshtra
# 9         NaN  Mahārāshtra
# 10     400001  Mahārāshtra
# 11     400023  Mahārāshtra
# 12        NaN          NaN
# 13        NaN          NaN
# 14     400001  Mahārāshtra
# 15        NaN          NaN
# 16        NaN  Mahārāshtra
# 17        NaN  Mahārāshtra
# 18        NaN          NaN
# 19        NaN  Mahārāshtra
# 20        NaN          NaN
# 21     400001  Mahārāshtra
# 22     400001  Mahārāshtra
# 23        NaN          NaN
# 24        NaN  Mahārāshtra
# 25        NaN  Mahārāshtra
# 26     400023  Mahārāshtra

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                      name            categories  \
# 0         Residency Hotel                 Hotel
# 1   Hotel Traveller’s Inn       Bed & Breakfast
# 8     Hotel Landmark Fort       Bed & Breakfast
# 14     Hotel Anand Bhuvan  Fast Food Restaurant
# 21           Deluxe Hotel   Housing Development
# 22         Benazeer Hotel                 Hotel
# 26       New Anand Bhavan  Fast Food Restaurant
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 1                                26, ADI Marzban Path  18.936039  72.838000
# 8                                  249 P D Mello Road  18.938528  72.837998
# 14                  Opposite Shahid bhagat Singh Road  18.935345  72.836884
# 21                       287 Shahid Bhagat Singh Road  18.935690  72.837398
# 22                                   16 Gunbow Street  18.935140  72.833948
# 26                                        Sheri House  18.934656  72.834848
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 1      400001  Mahārāshtra
# 8      400001  Mahārāshtra
# 14     400001  Mahārāshtra
# 21     400001  Mahārāshtra
# 22     400001  Mahārāshtra
# 26     400023  Mahārāshtra

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                name categories  \
# 0   Residency Hotel      Hotel
# 22   Benazeer Hotel      Hotel
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 22                                   16 Gunbow Street  18.935140  72.833948
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 22     400001  Mahārāshtra

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                name categories  \
# 0   Residency Hotel      Hotel
# 22   Benazeer Hotel      Hotel
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 22                                   16 Gunbow Street  18.935140  72.833948
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 22     400001  Mahārāshtra

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == '400001']
df_hotel
# Out:
#                name categories  \
# 0   Residency Hotel      Hotel
# 22   Benazeer Hotel      Hotel
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 22                                   16 Gunbow Street  18.935140  72.833948
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 22     400001  Mahārāshtra

# %% [markdown]
# # Search for Parks

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=A3CTF34TTNS3DT2QNQO2ED1FJPDBRIGV4CMJNPYBLOFMSHSS&client_secret=C02Q4L0GFUDV0YETTRQ11Z0OY1H4QVSZUZ5PUYCJ2SJKVFE1&ll=18.9387711,72.8353355&v=20191108&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
presults
# Out:
# {'meta': {'code': 200, 'requestId': '5dc7c0c4a30619002ca8b19f'},
#  'response': {'venues': [{'id': '4c9174ec238c6dcb067ec055',
#     'name': 'Priyadarshini Park',
#     'location': {'address': 'Nepean Sea Road',
#      'lat': 18.95751519120163,
#      'lng': 72.79961414024795,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.95751519120163,
#        'lng': 72.79961414024795}],
#      'distance': 4301,
#      'postalCode': '400006',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Nepean Sea Road',
#       'Mumbai 400006',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '511e3da9e4b092d8057a44b6',
#     'name': "Harish Mahindra Children's Park",
#     'location': {'address': 'Breach Candy, Behind American Counsulate',
#      'crossStreet': 'Bhulabhai Desai Road',
#      'lat': 18.91486679408915,
#      'lng': 72.82368836509063,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.91486679408915,
#        'lng': 72.82368836509063}],
#      'distance': 2930,
#      'postalCode': '400026',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Breach Candy, Behind American Counsulate (Bhulabhai Desai Road)',
#       'Mumbai 400026',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4c21b5b5502b952168d36d21',
#     'name': 'Peninsula Corporate Park',
#     'location': {'address': 'Lower Parel',
#      'crossStreet': 'G K Marg',
#      'lat': 18.99862608309867,
#      'lng': 72.82540798187256,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.99862608309867,
#        'lng': 72.82540798187256}],
#      'distance': 6744,
#      'postalCode': '400013',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Lower Parel (G K Marg)',
#       'Mumbai 400013',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4c84af7ed34ca14342c74080',
#     'name': 'Park Avenue',
#     'location': {'address': 'in High Street Phoenix,',
#      'lat': 18.99698589447507,
#      'lng': 72.82667728146514,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.99698589447507,
#        'lng': 72.82667728146514}],
#      'distance': 6544,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['in High Street Phoenix,',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '52f2771d11d2afc107a8206d',
#     'name': 'Traditions at Reagan Park',
#     'location': {'address': '1176 Kingwood Drive',
#      'lat': 18.94980408771263,
#      'lng': 72.83469915390015,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.94980408771263,
#        'lng': 72.83469915390015}],
#      'distance': 1230,
#      'postalCode': '46123',
#      'cc': 'IN',
#      'city': 'Avon',
#      'state': 'Indiana',
#      'country': 'India',
#      'formattedAddress': ['1176 Kingwood Drive',
#       'Avon 46123',
#       'Indiana',
#       'India']},
#     'categories': [{'id': '5267e4d9e4b0ec79466e48c6',
#       'name': 'Conference',
#       'pluralName': 'Conferences',
#       'shortName': 'Conference',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/event/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '5b430c7f2b274a002c36a513',
#     'name': 'Rivali Park',
#     'location': {'address': 'Rivali Park, Western Express Highway,Borivali (E), Mumbai 400 066',
#      'lat': 18.92959945134227,
#      'lng': 72.82818138599396,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.92959945134227,
#        'lng': 72.82818138599396}],
#      'distance': 1268,
#      'postalCode': '400066',
#      'cc': 'IN',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Rivali Park, Western Express Highway,Borivali (E), Mumbai 400 066',
#       'borivali 400066',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '5032885091d4c4b30a586d66',
#       'name': 'Real Estate Office',
#       'pluralName': 'Real Estate Offices',
#       'shortName': 'Real Estate',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '50bf18aee4b0baad55445f6f',
#     'name': 'Park Avenue',
#     'location': {'address': 'Shop No. 32/34, Churchgate House, Veer Nariman Road, Fort',
#      'crossStreet': 'Shahid Bhagat Singh Road',
#      'lat': 18.9202138084629,
#      'lng': 72.8301508410193,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.9202138084629,
#        'lng': 72.8301508410193}],
#      'distance': 2136,
#      'postalCode': '400001',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Shop No. 32/34, Churchgate House, Veer Nariman Road, Fort (Shahid Bhagat Singh Road)',
#       'Mumbai 400001',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d106951735',
#       'name': "Men's Store",
#       'pluralName': "Men's Stores",
#       'shortName': "Men's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4dc3c04cb0fb5556ccc514d9',
#     'name': 'One Avighna Park',
#     'location': {'address': 'Mahadev Palav Marg, Parel',
#      'crossStreet': 'Mahadev Palav Marg, Parel',
#      'lat': 18.99404075224203,
#      'lng': 72.83480644226074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.99404075224203,
#        'lng': 72.83480644226074}],
#      'distance': 6152,
#      'postalCode': '400012',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mahadev Palav Marg, Parel (Mahadev Palav Marg, Parel)',
#       'Mumbai 400012',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'shortName': 'Housing Development',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '90109480'},
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4c1e0f17b4e62d7ff1a2dd93',
#     'name': 'Bhakti Park',
#     'location': {'address': 'Near Imax Adlabs',
#      'crossStreet': 'Wadala',
#      'lat': 19.02767011619118,
#      'lng': 72.8800099930737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 19.02767011619118,
#        'lng': 72.8800099930737}],
#      'distance': 10956,
#      'postalCode': '400037',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Near Imax Adlabs (Wadala)',
#       'Mumbai 400037',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'shortName': 'Housing Development',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '5853519c876ade7856025db8',
#     'name': 'Hotel Residency Park',
#     'location': {'lat': 18.953255,
#      'lng': 72.83532,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.953255,
#        'lng': 72.83532}],
#      'distance': 1612,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '585351787220e62803a3a51c',
#     'name': 'Hotel Residency Park',
#     'location': {'lat': 18.95312,
#      'lng': 72.835175,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.95312,
#        'lng': 72.835175}],
#      'distance': 1597,
#      'postalCode': '400003',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Mumbai 400003', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '516a8116e4b0115526434f06',
#     'name': 'saifee park',
#     'location': {'lat': 18.972489444087074,
#      'lng': 72.83965383171211,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.972489444087074,
#        'lng': 72.83965383171211}],
#      'distance': 3780,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4ff0690de4b0616aaabe2632',
#     'name': 'Badhwar Park',
#     'location': {'address': 'Wodehouse Road',
#      'crossStreet': 'Cuffe Parade',
#      'lat': 18.919159561453558,
#      'lng': 72.82664843109578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.919159561453558,
#        'lng': 72.82664843109578}],
#      'distance': 2367,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Wodehouse Road (Cuffe Parade)',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'shortName': 'Housing Development',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4fd6a4c4e4b0555736523835',
#     'name': 'Bhakti Park Monorail Station',
#     'location': {'address': 'Bhakti Park',
#      'crossStreet': 'Wadala',
#      'lat': 19.029101034315968,
#      'lng': 72.87762746453538,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 19.029101034315968,
#        'lng': 72.87762746453538}],
#      'distance': 10996,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Bhakti Park (Wadala)',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'shortName': 'Light Rail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '5314ae51e4b0d805d3725d79',
#     'name': 'Badhwar Park',
#     'location': {'lat': 18.9211,
#      'lng': 72.8273,
#      'labeledLatLngs': [{'label': 'display', 'lat': 18.9211, 'lng': 72.8273}],
#      'distance': 2141,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4f2a25ac4b909258e854f55f',
#       'name': 'Neighborhood',
#       'pluralName': 'Neighborhoods',
#       'shortName': 'Neighborhood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4ebcd56b02d5e32b7b99c0a4',
#     'name': 'Kanha National Park',
#     'location': {'lat': 18.9230368,
#      'lng': 72.8229863,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.9230368,
#        'lng': 72.8229863}],
#      'distance': 2181,
#      'cc': 'IN',
#      'state': 'Madhya Pradesh',
#      'country': 'India',
#      'formattedAddress': ['Madhya Pradesh', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d162941735',
#       'name': 'Other Great Outdoors',
#       'pluralName': 'Other Great Outdoors',
#       'shortName': 'Other Outdoors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '5066fcabe4b089084766b1c3',
#     'name': 'Park Shilton',
#     'location': {'lat': 18.9657628,
#      'lng': 72.8192817,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.9657628,
#        'lng': 72.8192817}],
#      'distance': 3447,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4f4b4f24e4b007d391a92493',
#     'name': 'Traffic Park',
#     'location': {'address': 'Cooperage Rd, Colaba, Mumbai, Maharashtra',
#      'lat': 18.91884355714035,
#      'lng': 72.82593294084563,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.91884355714035,
#        'lng': 72.82593294084563}],
#      'distance': 2429,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Cooperage Rd, Colaba, Mumbai, Maharashtra',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '51f5170e498e64a853194c85',
#     'name': 'Park View',
#     'location': {'lat': 18.973325729370117,
#      'lng': 72.8239974975586,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.973325729370117,
#        'lng': 72.8239974975586}],
#      'distance': 4027,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4cb1c8a775ebb60ceda8cfad',
#     'name': 'Badhwar Park',
#     'location': {'address': 'Colaba',
#      'lat': 18.918839346876087,
#      'lng': 72.82805121453612,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.918839346876087,
#        'lng': 72.82805121453612}],
#      'distance': 2347,
#      'postalCode': '400005',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Colaba', 'Mumbai 400005', 'Mahārāshtra', 'India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4d7cb1decf3f37047aa65540',
#     'name': 'Oomer Park',
#     'location': {'address': 'Bhulabhai Desai Road',
#      'lat': 18.96610966482043,
#      'lng': 72.80514441667448,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.96610966482043,
#        'lng': 72.80514441667448}],
#      'distance': 4400,
#      'postalCode': '400026',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Bhulabhai Desai Road',
#       'Mumbai 400026',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4b0587d1f964a520e3a222e3',
#     'name': 'Kamala Nehru Park',
#     'location': {'address': 'B G Kher Road',
#      'lat': 18.94989849228201,
#      'lng': 72.80131797796678,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.94989849228201,
#        'lng': 72.80131797796678}],
#      'distance': 3789,
#      'postalCode': '400 026',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['B G Kher Road',
#       'Mumbai 400 026',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d12d941735',
#       'name': 'Monument / Landmark',
#       'pluralName': 'Monuments / Landmarks',
#       'shortName': 'Landmark',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4d04eaaa28926ea831176ec2',
#     'name': 'China Garden Shivaji Park ¤',
#     'location': {'address': 'Cadell Road, Opposite Catering College',
#      'lat': 19.023243845684675,
#      'lng': 72.83514760241242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 19.023243845684675,
#        'lng': 72.83514760241242}],
#      'distance': 9403,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Cadell Road, Opposite Catering College',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4f6a8f9ae4b09b90a9b402b7',
#     'name': "Land's End Park",
#     'location': {'lat': 18.916560776710114,
#      'lng': 72.81636594255629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.916560776710114,
#        'lng': 72.81636594255629}],
#      'distance': 3178,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4f4c10fbe4b088c4acb94104',
#     'name': 'Saifee Burhani Park',
#     'location': {'lat': 18.972707848888493,
#      'lng': 72.84273486750885,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.972707848888493,
#        'lng': 72.84273486750885}],
#      'distance': 3857,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4f4d2395e4b088c4ade5fb2a',
#     'name': 'Hill Park',
#     'location': {'address': 'Malabar Hill',
#      'crossStreet': 'A.G.Bell Marg',
#      'lat': 18.951896662874148,
#      'lng': 72.7991294000465,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.951896662874148,
#        'lng': 72.7991294000465}],
#      'distance': 4082,
#      'postalCode': '400006',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Malabar Hill (A.G.Bell Marg)',
#       'Mumbai 400006',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4b0587d2f964a52014a322e3',
#     'name': 'Shivaji Park',
#     'location': {'address': 'Swatantrya Veer Savarkar Marg',
#      'lat': 19.026621409220052,
#      'lng': 72.84103268261613,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 19.026621409220052,
#        'lng': 72.84103268261613}],
#      'distance': 9797,
#      'postalCode': '400 028',
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Swatantrya Veer Savarkar Marg',
#       'Mumbai 400 028',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1e7941735',
#       'name': 'Playground',
#       'pluralName': 'Playgrounds',
#       'shortName': 'Playground',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4cb9b52f0180721e1f999561',
#     'name': 'Amarsons Park, Breach Candy',
#     'location': {'lat': 18.972316882196097,
#      'lng': 72.80632673666895,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.972316882196097,
#        'lng': 72.80632673666895}],
#      'distance': 4824,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4fc20d9be4b0e4e80d26613e',
#     'name': 'Park Avenue Women',
#     'location': {'lat': 18.9951853895044,
#      'lng': 72.82455965530025,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.9951853895044,
#        'lng': 72.82455965530025}],
#      'distance': 6381,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False},
#    {'id': '4c3dce9cb36ac928d9e70586',
#     'name': 'Park Avenue',
#     'location': {'address': 'Sky Zone, phoenix mills',
#      'crossStreet': 'Senapati bapat marg',
#      'lat': 18.99505103371176,
#      'lng': 72.8236191233513,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.99505103371176,
#        'lng': 72.8236191233513}],
#      'distance': 6385,
#      'cc': 'IN',
#      'city': 'Mumbai',
#      'state': 'Mahārāshtra',
#      'country': 'India',
#      'formattedAddress': ['Sky Zone, phoenix mills (Senapati bapat marg)',
#       'Mumbai',
#       'Mahārāshtra',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1573372100',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...    False
# 3  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...    False
# 4  [{'id': '5267e4d9e4b0ec79466e48c6', 'name': 'C...    False
#
#                          id                          location.address  \
# 0  4c9174ec238c6dcb067ec055                           Nepean Sea Road
# 1  511e3da9e4b092d8057a44b6  Breach Candy, Behind American Counsulate
# 2  4c21b5b5502b952168d36d21                               Lower Parel
# 3  4c84af7ed34ca14342c74080                   in High Street Phoenix,
# 4  52f2771d11d2afc107a8206d                       1176 Kingwood Drive
#
#   location.cc location.city location.country  location.crossStreet  \
# 0          IN        Mumbai            India                   NaN
# 1          IN        Mumbai            India  Bhulabhai Desai Road
# 2          IN        Mumbai            India              G K Marg
# 3          IN        Mumbai            India                   NaN
# 4          IN          Avon            India                   NaN
#
#    location.distance                          location.formattedAddress  \
# 0               4301  [Nepean Sea Road, Mumbai 400006, Mahārāshtra, ...
# 1               2930  [Breach Candy, Behind American Counsulate (Bhu...
# 2               6744  [Lower Parel (G K Marg), Mumbai 400013, Mahārā...
# 3               6544  [in High Street Phoenix,, Mumbai, Mahārāshtra,...
# 4               1230  [1176 Kingwood Drive, Avon 46123, Indiana, India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 18.95751519120163...     18.957515
# 1  [{'label': 'display', 'lat': 18.91486679408915...     18.914867
# 2  [{'label': 'display', 'lat': 18.99862608309867...     18.998626
# 3  [{'label': 'display', 'lat': 18.99698589447507...     18.996986
# 4  [{'label': 'display', 'lat': 18.94980408771263...     18.949804
#
#    location.lng location.postalCode location.state  \
# 0     72.799614              400006    Mahārāshtra
# 1     72.823688              400026    Mahārāshtra
# 2     72.825408              400013    Mahārāshtra
# 3     72.826677                 NaN    Mahārāshtra
# 4     72.834699               46123        Indiana
#
#                               name    referralId venuePage.id
# 0               Priyadarshini Park  v-1573372100          NaN
# 1  Harish Mahindra Children's Park  v-1573372100          NaN
# 2         Peninsula Corporate Park  v-1573372100          NaN
# 3                      Park Avenue  v-1573372100          NaN
# 4        Traditions at Reagan Park  v-1573372100          NaN

# %% [markdown]
# # Clean Park Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                               name      categories  \
# 0               Priyadarshini Park            Park
# 1  Harish Mahindra Children's Park            Park
# 2         Peninsula Corporate Park        Building
# 3                      Park Avenue  Clothing Store
# 4        Traditions at Reagan Park      Conference
#
#                                     address  cc    city country  \
# 0                           Nepean Sea Road  IN  Mumbai   India
# 1  Breach Candy, Behind American Counsulate  IN  Mumbai   India
# 2                               Lower Parel  IN  Mumbai   India
# 3                   in High Street Phoenix,  IN  Mumbai   India
# 4                       1176 Kingwood Drive  IN    Avon   India
#
#             crossStreet  distance  \
# 0                   NaN      4301
# 1  Bhulabhai Desai Road      2930
# 2              G K Marg      6744
# 3                   NaN      6544
# 4                   NaN      1230
#
#                                     formattedAddress  \
# 0  [Nepean Sea Road, Mumbai 400006, Mahārāshtra, ...
# 1  [Breach Candy, Behind American Counsulate (Bhu...
# 2  [Lower Parel (G K Marg), Mumbai 400013, Mahārā...
# 3  [in High Street Phoenix,, Mumbai, Mahārāshtra,...
# 4  [1176 Kingwood Drive, Avon 46123, Indiana, India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 18.95751519120163...  18.957515  72.799614
# 1  [{'label': 'display', 'lat': 18.91486679408915...  18.914867  72.823688
# 2  [{'label': 'display', 'lat': 18.99862608309867...  18.998626  72.825408
# 3  [{'label': 'display', 'lat': 18.99698589447507...  18.996986  72.826677
# 4  [{'label': 'display', 'lat': 18.94980408771263...  18.949804  72.834699
#
#   postalCode        state                        id
# 0     400006  Mahārāshtra  4c9174ec238c6dcb067ec055
# 1     400026  Mahārāshtra  511e3da9e4b092d8057a44b6
# 2     400013  Mahārāshtra  4c21b5b5502b952168d36d21
# 3        NaN  Mahārāshtra  4c84af7ed34ca14342c74080
# 4      46123      Indiana  52f2771d11d2afc107a8206d

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                name                                categories  \
# 0                Priyadarshini Park                                      Park
# 1   Harish Mahindra Children's Park                                      Park
# 2          Peninsula Corporate Park                                  Building
# 3                       Park Avenue                            Clothing Store
# 4         Traditions at Reagan Park                                Conference
# 5                       Rivali Park                        Real Estate Office
# 6                       Park Avenue                               Men's Store
# 7                  One Avighna Park                       Housing Development
# 8                       Bhakti Park                       Housing Development
# 9              Hotel Residency Park                                     Hotel
# 10             Hotel Residency Park                                     Hotel
# 11                      saifee park  Residential Building (Apartment / Condo)
# 12                     Badhwar Park                       Housing Development
# 13     Bhakti Park Monorail Station                        Light Rail Station
# 14                     Badhwar Park                              Neighborhood
# 15              Kanha National Park                      Other Great Outdoors
# 16                     Park Shilton                                Restaurant
# 17                     Traffic Park                                      Park
# 18                        Park View  Residential Building (Apartment / Condo)
# 19                     Badhwar Park  Residential Building (Apartment / Condo)
# 20                       Oomer Park  Residential Building (Apartment / Condo)
# 21                Kamala Nehru Park                       Monument / Landmark
# 22      China Garden Shivaji Park ¤                        Chinese Restaurant
# 23                  Land's End Park                                      Park
# 24              Saifee Burhani Park  Residential Building (Apartment / Condo)
# 25                        Hill Park  Residential Building (Apartment / Condo)
# 26                     Shivaji Park                                Playground
# 27      Amarsons Park, Breach Candy                                      Park
# 28                Park Avenue Women                             Women's Store
# 29                      Park Avenue                            Clothing Store
#
#                                               address        lat        lng  \
# 0                                     Nepean Sea Road  18.957515  72.799614
# 1            Breach Candy, Behind American Counsulate  18.914867  72.823688
# 2                                         Lower Parel  18.998626  72.825408
# 3                             in High Street Phoenix,  18.996986  72.826677
# 4                                 1176 Kingwood Drive  18.949804  72.834699
# 5   Rivali Park, Western Express Highway,Borivali ...  18.929599  72.828181
# 6   Shop No. 32/34, Churchgate House, Veer Nariman...  18.920214  72.830151
# 7                           Mahadev Palav Marg, Parel  18.994041  72.834806
# 8                                    Near Imax Adlabs  19.027670  72.880010
# 9                                                 NaN  18.953255  72.835320
# 10                                                NaN  18.953120  72.835175
# 11                                                NaN  18.972489  72.839654
# 12                                     Wodehouse Road  18.919160  72.826648
# 13                                        Bhakti Park  19.029101  72.877627
# 14                                                NaN  18.921100  72.827300
# 15                                                NaN  18.923037  72.822986
# 16                                                NaN  18.965763  72.819282
# 17          Cooperage Rd, Colaba, Mumbai, Maharashtra  18.918844  72.825933
# 18                                                NaN  18.973326  72.823997
# 19                                             Colaba  18.918839  72.828051
# 20                               Bhulabhai Desai Road  18.966110  72.805144
# 21                                      B G Kher Road  18.949898  72.801318
# 22             Cadell Road, Opposite Catering College  19.023244  72.835148
# 23                                                NaN  18.916561  72.816366
# 24                                                NaN  18.972708  72.842735
# 25                                       Malabar Hill  18.951897  72.799129
# 26                      Swatantrya Veer Savarkar Marg  19.026621  72.841033
# 27                                                NaN  18.972317  72.806327
# 28                                                NaN  18.995185  72.824560
# 29                            Sky Zone, phoenix mills  18.995051  72.823619
#
#    postalCode           state
# 0      400006     Mahārāshtra
# 1      400026     Mahārāshtra
# 2      400013     Mahārāshtra
# 3         NaN     Mahārāshtra
# 4       46123         Indiana
# 5      400066     Mahārāshtra
# 6      400001     Mahārāshtra
# 7      400012     Mahārāshtra
# 8      400037     Mahārāshtra
# 9         NaN             NaN
# 10     400003     Mahārāshtra
# 11        NaN             NaN
# 12        NaN     Mahārāshtra
# 13        NaN     Mahārāshtra
# 14        NaN             NaN
# 15        NaN  Madhya Pradesh
# 16        NaN             NaN
# 17        NaN     Mahārāshtra
# 18        NaN             NaN
# 19     400005     Mahārāshtra
# 20     400026     Mahārāshtra
# 21    400 026     Mahārāshtra
# 22        NaN     Mahārāshtra
# 23        NaN             NaN
# 24        NaN             NaN
# 25     400006     Mahārāshtra
# 26    400 028     Mahārāshtra
# 27        NaN             NaN
# 28        NaN             NaN
# 29        NaN     Mahārāshtra

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                name                                categories  \
# 0                Priyadarshini Park                                      Park
# 1   Harish Mahindra Children's Park                                      Park
# 2          Peninsula Corporate Park                                  Building
# 4         Traditions at Reagan Park                                Conference
# 5                       Rivali Park                        Real Estate Office
# 6                       Park Avenue                               Men's Store
# 7                  One Avighna Park                       Housing Development
# 8                       Bhakti Park                       Housing Development
# 19                     Badhwar Park  Residential Building (Apartment / Condo)
# 20                       Oomer Park  Residential Building (Apartment / Condo)
# 21                Kamala Nehru Park                       Monument / Landmark
# 25                        Hill Park  Residential Building (Apartment / Condo)
# 26                     Shivaji Park                                Playground
#
#                                               address        lat        lng  \
# 0                                     Nepean Sea Road  18.957515  72.799614
# 1            Breach Candy, Behind American Counsulate  18.914867  72.823688
# 2                                         Lower Parel  18.998626  72.825408
# 4                                 1176 Kingwood Drive  18.949804  72.834699
# 5   Rivali Park, Western Express Highway,Borivali ...  18.929599  72.828181
# 6   Shop No. 32/34, Churchgate House, Veer Nariman...  18.920214  72.830151
# 7                           Mahadev Palav Marg, Parel  18.994041  72.834806
# 8                                    Near Imax Adlabs  19.027670  72.880010
# 19                                             Colaba  18.918839  72.828051
# 20                               Bhulabhai Desai Road  18.966110  72.805144
# 21                                      B G Kher Road  18.949898  72.801318
# 25                                       Malabar Hill  18.951897  72.799129
# 26                      Swatantrya Veer Savarkar Marg  19.026621  72.841033
#
#    postalCode        state
# 0      400006  Mahārāshtra
# 1      400026  Mahārāshtra
# 2      400013  Mahārāshtra
# 4       46123      Indiana
# 5      400066  Mahārāshtra
# 6      400001  Mahārāshtra
# 7      400012  Mahārāshtra
# 8      400037  Mahārāshtra
# 19     400005  Mahārāshtra
# 20     400026  Mahārāshtra
# 21    400 026  Mahārāshtra
# 25     400006  Mahārāshtra
# 26    400 028  Mahārāshtra

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                               name categories  \
# 0               Priyadarshini Park       Park
# 1  Harish Mahindra Children's Park       Park
#
#                                     address        lat        lng postalCode  \
# 0                           Nepean Sea Road  18.957515  72.799614     400006
# 1  Breach Candy, Behind American Counsulate  18.914867  72.823688     400026
#
#          state
# 0  Mahārāshtra
# 1  Mahārāshtra

# %% [markdown]
# # Search for Restaurants

# %%
# search for Cafeteria
search_query = 'Restaurant'
radius = 5000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=A3CTF34TTNS3DT2QNQO2ED1FJPDBRIGV4CMJNPYBLOFMSHSS&client_secret=C02Q4L0GFUDV0YETTRQ11Z0OY1H4QVSZUZ5PUYCJ2SJKVFE1&ll=18.9387711,72.8353355&v=20191108&query=Restaurant&radius=5000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
#
#                          id             location.address location.cc  \
# 0  5263f0f5498edc1ad5f3270f           Near GPO, Fort, VT          IN
# 1  4e4c0a4122713bd908c641ff                 Opposite GPO          IN
# 2  4c09449eed2595217aee1256            Veer Nariman Road          IN
# 3  4f489f23e4b018635344413a            Opp. Metro Cinema          IN
# 4  4fb5276be4b0b34b9ac27a1b  Palton Road, Near Haj House          IN
#
#   location.city location.country                location.crossStreet  \
# 0        Mumbai            India                S. Bhagat Singh Road
# 1        Mumbai            India                      Ballard Estate
# 2        Mumbai            India  Next to Vodafone Store, Churchgate
# 3        Mumbai            India                        Marine Lines
# 4        Mumbai            India                                 NaN
#
#    location.distance                          location.formattedAddress  \
# 0                260  [Near GPO, Fort, VT (S. Bhagat Singh Road), Mu...
# 1                280  [Opposite GPO (Ballard Estate), Mumbai, Mahārā...
# 2               1082  [Veer Nariman Road (Next to Vodafone Store, Ch...
# 3               1007  [Opp. Metro Cinema (Marine Lines), Mumbai, Mah...
# 4                747  [Palton Road, Near Haj House, Mumbai 400001, M...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 18.93797448587734...     18.937974
# 1  [{'label': 'display', 'lat': 18.93816453050136...     18.938165
# 2  [{'label': 'display', 'lat': 18.93317339191467...     18.933173
# 3  [{'label': 'display', 'lat': 18.94289961203775...     18.942900
# 4  [{'label': 'display', 'lat': 18.94534293649397...     18.945343
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0     72.837663                   NaN              400001    Mahārāshtra
# 1     72.837917                   NaN                 NaN    Mahārāshtra
# 2     72.826929                   NaN              400023    Mahārāshtra
# 3     72.826820                   NaN                 NaN    Mahārāshtra
# 4     72.836809                   NaN              400001    Mahārāshtra
#
#                                 name    referralId
# 0  Nanumal Bhojraj Restaurant - Fort  v-1573372107
# 1                 Farhang Restaurant  v-1573372107
# 2        Stadium Restaurant & Stores  v-1573372107
# 3        Panchratna restaurant & bar  v-1573372107
# 4               Iran Like Restaurant  v-1573372107

# %% [markdown]
# # Clean Restaurant dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                 name         categories  \
# 0  Nanumal Bhojraj Restaurant - Fort  Indian Restaurant
# 1                 Farhang Restaurant         Steakhouse
# 2        Stadium Restaurant & Stores  Indian Restaurant
# 3        Panchratna restaurant & bar  Indian Restaurant
# 4               Iran Like Restaurant  Indian Restaurant
#
#                        address  cc    city country  \
# 0           Near GPO, Fort, VT  IN  Mumbai   India
# 1                 Opposite GPO  IN  Mumbai   India
# 2            Veer Nariman Road  IN  Mumbai   India
# 3            Opp. Metro Cinema  IN  Mumbai   India
# 4  Palton Road, Near Haj House  IN  Mumbai   India
#
#                           crossStreet  distance  \
# 0                S. Bhagat Singh Road       260
# 1                      Ballard Estate       280
# 2  Next to Vodafone Store, Churchgate      1082
# 3                        Marine Lines      1007
# 4                                 NaN       747
#
#                                     formattedAddress  \
# 0  [Near GPO, Fort, VT (S. Bhagat Singh Road), Mu...
# 1  [Opposite GPO (Ballard Estate), Mumbai, Mahārā...
# 2  [Veer Nariman Road (Next to Vodafone Store, Ch...
# 3  [Opp. Metro Cinema (Marine Lines), Mumbai, Mah...
# 4  [Palton Road, Near Haj House, Mumbai 400001, M...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 18.93797448587734...  18.937974  72.837663
# 1  [{'label': 'display', 'lat': 18.93816453050136...  18.938165  72.837917
# 2  [{'label': 'display', 'lat': 18.93317339191467...  18.933173  72.826929
# 3  [{'label': 'display', 'lat': 18.94289961203775...  18.942900  72.826820
# 4  [{'label': 'display', 'lat': 18.94534293649397...  18.945343  72.836809
#
#   neighborhood postalCode        state                        id
# 0          NaN     400001  Mahārāshtra  5263f0f5498edc1ad5f3270f
# 1          NaN        NaN  Mahārāshtra  4e4c0a4122713bd908c641ff
# 2          NaN     400023  Mahārāshtra  4c09449eed2595217aee1256
# 3          NaN        NaN  Mahārāshtra  4f489f23e4b018635344413a
# 4          NaN     400001  Mahārāshtra  4fb5276be4b0b34b9ac27a1b

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',
                                        'neighborhood','labeledLatLngs', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                           name                     categories  \
# 0            Nanumal Bhojraj Restaurant - Fort              Indian Restaurant
# 1                           Farhang Restaurant                     Steakhouse
# 2                  Stadium Restaurant & Stores              Indian Restaurant
# 3                  Panchratna restaurant & bar              Indian Restaurant
# 4                         Iran Like Restaurant              Indian Restaurant
# 5                      New Majestic Restaurant              Indian Restaurant
# 6                         Sai Pooja Restaurant                           None
# 7                            Poonam Restaurant                     Restaurant
# 8                              Aram Restaurant               Asian Restaurant
# 9   Nanumal Bhojraj Restaurant - Masjid Bunder              Indian Restaurant
# 10                          Kalpana restaurant                           None
# 11                         National Restaurant                           Food
# 12                     Golden Wheel Restaurant                     Restaurant
# 13                          Kamat's Restaurant              Indian Restaurant
# 14                          Ustaadi Restaurant                         Lounge
# 15                      Royal China Restaurant           Cantonese Restaurant
# 16                          Gulshan Restaurant              Indian Restaurant
# 17                         Brighton Restaurant                     Restaurant
# 18                Sind Punjab Bar & Restaurant                     Restaurant
# 19                   Mangalore naaz Restaurant               Asian Restaurant
# 20                           Canara Restaurant              Indian Restaurant
# 21                Fountain Sizzlers Restaurant              Indian Restaurant
# 22                    Anubhav Restaurant & Bar              Indian Restaurant
# 23                           Bombay Restaurant              Indian Restaurant
# 24                       queen mary restaurant                           Café
# 25                      Excellensea Restaurant                      BBQ Joint
# 26                         Goodluck Restaurant                           None
# 27                           Khyber Restaurant              Indian Restaurant
# 28                       Samrat Veg Restaurant  Vegetarian / Vegan Restaurant
# 29                          Gaylord Restaurant              Indian Restaurant
#
#                                               address        lat        lng  \
# 0                                  Near GPO, Fort, VT  18.937974  72.837663
# 1                                        Opposite GPO  18.938165  72.837917
# 2                                   Veer Nariman Road  18.933173  72.826929
# 3                                   Opp. Metro Cinema  18.942900  72.826820
# 4                         Palton Road, Near Haj House  18.945343  72.836809
# 5                                             Opp CST  18.938972  72.835517
# 6                                                 NaN  18.938357  72.835073
# 7                                                 NaN  18.939225  72.835707
# 8                           Capitol building, DN Road  18.939543  72.834495
# 9   Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 10                                                Gpo  18.937489  72.836157
# 11                                    opp fort market  18.935112  72.836896
# 12                                            Girgaon  18.954636  72.819690
# 13                        Opp. Electric House, Colaba  18.921570  72.831004
# 14                          B Block, Sitaram Building  18.945482  72.834270
# 15                                                NaN  18.937876  72.831005
# 16                                                NaN  18.938199  72.837764
# 17                                                NaN  18.935007  72.833687
# 18                        263, SBS Road, Fort, Mumbai  18.937048  72.837381
# 19                                                NaN  18.937245  72.837606
# 20                                                NaN  18.936847  72.837525
# 21                             57 Mahatma Gandhi Road  18.931366  72.831462
# 22                                                NaN  18.936497  72.837586
# 23                                                NaN  18.935902  72.834426
# 24                                                NaN  18.969932  72.835495
# 25                                          Mint Road  18.935266  72.837240
# 26                                                NaN  18.935578  72.837357
# 27                   Kalaghoda, 145 Mahatma Gandhi Rd  18.928134  72.831541
# 28                                    J. D. Tata Road  18.930674  72.826320
# 29                                         V. N. Road  18.932948  72.826127
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 1         NaN  Mahārāshtra
# 2      400023  Mahārāshtra
# 3         NaN  Mahārāshtra
# 4      400001  Mahārāshtra
# 5         NaN  Mahārāshtra
# 6         NaN  Mahārāshtra
# 7         NaN          NaN
# 8         NaN  Mahārāshtra
# 9      400009  Mahārāshtra
# 10        NaN  Mahārāshtra
# 11     400001  Mahārāshtra
# 12        NaN  Mahārāshtra
# 13        NaN  Mahārāshtra
# 14     400001  Mahārāshtra
# 15        NaN          NaN
# 16     400001  Mahārāshtra
# 17        NaN          NaN
# 18        NaN          NaN
# 19        NaN          NaN
# 20        NaN          NaN
# 21    400 023  Mahārāshtra
# 22     400001  Mahārāshtra
# 23        NaN  Mahārāshtra
# 24        NaN          NaN
# 25     400001  Mahārāshtra
# 26        NaN  Mahārāshtra
# 27    400 023  Mahārāshtra
# 28    400 020  Mahārāshtra
# 29    400 020  Mahārāshtra

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                           name                     categories  \
# 0            Nanumal Bhojraj Restaurant - Fort              Indian Restaurant
# 2                  Stadium Restaurant & Stores              Indian Restaurant
# 4                         Iran Like Restaurant              Indian Restaurant
# 9   Nanumal Bhojraj Restaurant - Masjid Bunder              Indian Restaurant
# 11                         National Restaurant                           Food
# 14                          Ustaadi Restaurant                         Lounge
# 21                Fountain Sizzlers Restaurant              Indian Restaurant
# 25                      Excellensea Restaurant                      BBQ Joint
# 27                           Khyber Restaurant              Indian Restaurant
# 28                       Samrat Veg Restaurant  Vegetarian / Vegan Restaurant
# 29                          Gaylord Restaurant              Indian Restaurant
#
#                                               address        lat        lng  \
# 0                                  Near GPO, Fort, VT  18.937974  72.837663
# 2                                   Veer Nariman Road  18.933173  72.826929
# 4                         Palton Road, Near Haj House  18.945343  72.836809
# 9   Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 11                                    opp fort market  18.935112  72.836896
# 14                          B Block, Sitaram Building  18.945482  72.834270
# 21                             57 Mahatma Gandhi Road  18.931366  72.831462
# 25                                          Mint Road  18.935266  72.837240
# 27                   Kalaghoda, 145 Mahatma Gandhi Rd  18.928134  72.831541
# 28                                    J. D. Tata Road  18.930674  72.826320
# 29                                         V. N. Road  18.932948  72.826127
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 2      400023  Mahārāshtra
# 4      400001  Mahārāshtra
# 9      400009  Mahārāshtra
# 11     400001  Mahārāshtra
# 14     400001  Mahārāshtra
# 21    400 023  Mahārāshtra
# 25     400001  Mahārāshtra
# 27    400 023  Mahārāshtra
# 28    400 020  Mahārāshtra
# 29    400 020  Mahārāshtra

# %% [markdown]
# # Generate map to visualize Hotel,Park and Restaurant and how they cluster together

# %%
# create dataframe of hotels, restaurants and parks
hotel_neighbourhood_df = pd.concat([df_hotel, df_Restaurant,df_park], ignore_index=True,sort=False)
hotel_neighbourhood_df
# Out:
#                                           name                     categories  \
# 0                              Residency Hotel                          Hotel
# 1                               Benazeer Hotel                          Hotel
# 2            Nanumal Bhojraj Restaurant - Fort              Indian Restaurant
# 3                  Stadium Restaurant & Stores              Indian Restaurant
# 4                         Iran Like Restaurant              Indian Restaurant
# 5   Nanumal Bhojraj Restaurant - Masjid Bunder              Indian Restaurant
# 6                          National Restaurant                           Food
# 7                           Ustaadi Restaurant                         Lounge
# 8                 Fountain Sizzlers Restaurant              Indian Restaurant
# 9                       Excellensea Restaurant                      BBQ Joint
# 10                           Khyber Restaurant              Indian Restaurant
# 11                       Samrat Veg Restaurant  Vegetarian / Vegan Restaurant
# 12                          Gaylord Restaurant              Indian Restaurant
# 13                          Priyadarshini Park                           Park
# 14             Harish Mahindra Children's Park                           Park
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 1                                    16 Gunbow Street  18.935140  72.833948
# 2                                  Near GPO, Fort, VT  18.937974  72.837663
# 3                                   Veer Nariman Road  18.933173  72.826929
# 4                         Palton Road, Near Haj House  18.945343  72.836809
# 5   Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 6                                     opp fort market  18.935112  72.836896
# 7                           B Block, Sitaram Building  18.945482  72.834270
# 8                              57 Mahatma Gandhi Road  18.931366  72.831462
# 9                                           Mint Road  18.935266  72.837240
# 10                   Kalaghoda, 145 Mahatma Gandhi Rd  18.928134  72.831541
# 11                                    J. D. Tata Road  18.930674  72.826320
# 12                                         V. N. Road  18.932948  72.826127
# 13                                    Nepean Sea Road  18.957515  72.799614
# 14           Breach Candy, Behind American Counsulate  18.914867  72.823688
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 1      400001  Mahārāshtra
# 2      400001  Mahārāshtra
# 3      400023  Mahārāshtra
# 4      400001  Mahārāshtra
# 5      400009  Mahārāshtra
# 6      400001  Mahārāshtra
# 7      400001  Mahārāshtra
# 8     400 023  Mahārāshtra
# 9      400001  Mahārāshtra
# 10    400 023  Mahārāshtra
# 11    400 020  Mahārāshtra
# 12    400 020  Mahārāshtra
# 13     400006  Mahārāshtra
# 14     400026  Mahārāshtra

# %%
# Generate map to visualize hotel neighbourhood including restaurants and parks 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        parse_html=False).add_to(hotel_map)  
    
# folium.CircleMarker(
#     [event_latitude, event_longitude],
#     radius=10,
#     color='red',
#     popup='Event location',
#     fill = True,
#     fill_color = 'red',
#     fill_opacity = 0.6
# ).add_to(hotel_map)    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Link

# %% [markdown]
# Link has been provided to view the map
#
# https://eu-gb.dataplatform.cloud.ibm.com/analytics/notebooks/v2/7d839f74-72d1-4e3d-8c0b-0d
